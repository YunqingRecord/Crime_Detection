# %%
file = open("data.txt")

# %%
txtline = []
for line in file.readlines():
    txtline.append(line)
txtline
# Out:
# ['0.20829200193682007 0.2628796733867071 0.26287967338670704 0.22328301736012793 0.16807845659048115 0.2811598353168575 0 0 0.2048604127074501 0.24463536829461618 0.24172028058162814 0.22328301736012796 0.2446353682946162 0.2601690859877866 0.22643558734798 0.22643558734798 0 0 \n',
#  '0.20829200193682007 0.26016908598778665 0.24463536829461618 0.22328301736012793 0.16807845659048115 0.2811598353168575 0 0 0.20829200193682007 0.24463536829461618 0.24463536829461624 0.22643558734798 0.2446353682946162 0.2601690859877866 0.22643558734798 0.22643558734798 0 0 \n',
#  '0.20829200193682007 0.2446353682946162 0.24463536829461618 0.22328301736012793 0.16807845659048115 0.262879673386707 0 0 0.2048604127074501 0.22643558734798 0.24172028058162814 0.22328301736012796 0.2446353682946162 0.2601690859877866 0.22643558734798 0.22643558734798 0 0 \n',
# ...

# %%
for i in range(len(txtline)):
    if i%20 == 19:
        pass
    else:
        txtline[i] = txtline[i][:-1]

# %%
file1 = open('data20.txt','w')

# %%
for i in txtline:
    file1.write(str(i))

# %%
file.close()

# %%
txtline
# Out:
# ['0.20829200193682007 0.2628796733867071 0.26287967338670704 0.22328301736012793 0.16807845659048115 0.2811598353168575 0 0 0.2048604127074501 0.24463536829461618 0.24172028058162814 0.22328301736012796 0.2446353682946162 0.2601690859877866 0.22643558734798 0.22643558734798 0 0 ',
#  '0.20829200193682007 0.26016908598778665 0.24463536829461618 0.22328301736012793 0.16807845659048115 0.2811598353168575 0 0 0.20829200193682007 0.24463536829461618 0.24463536829461624 0.22643558734798 0.2446353682946162 0.2601690859877866 0.22643558734798 0.22643558734798 0 0 ',
#  '0.20829200193682007 0.2446353682946162 0.24463536829461618 0.22328301736012793 0.16807845659048115 0.262879673386707 0 0 0.2048604127074501 0.22643558734798 0.24172028058162814 0.22328301736012796 0.2446353682946162 0.2601690859877866 0.22643558734798 0.22643558734798 0 0 ',
# ...

# %%
filenew = open("data20.txt")

# %%
txtline1 = []
for line in filenew.readlines():
    txtline1.append(line)
txtline1
# Out:
# []

# %%
txtls = txtline1[0].split(' ')
len(txtls)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-3f76ee4c4e13> in <module>
# ----> 1 txtls = txtline1[0].split(' ')
#       2 len(txtls)
#
# IndexError: list index out of range

# %%
file1.close()
